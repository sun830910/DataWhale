# %%
import os
import math
import gc

import pandas as pd
import numpy as np

import xgboost as xgb

from sklearn.linear_model import SGDRegressor, LinearRegression, Ridge
from sklearn.preprocessing import MinMaxScaler

from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.metrics import log_loss
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

import matplotlib.pyplot as plt
import time
import warnings
warnings.filterwarnings('ignore')

from keras.models import Sequential
from keras.layers import Flatten, Dense, Embedding, LSTM
from keras.utils import to_categorical

# %%
data_path = '/Users/chiang/数据/天池-心跳信号分类预测/'
data_train = pd.read_csv(data_path + 'train.csv')
data_test_A = pd.read_csv(data_path + 'testA.csv')

# %%
data_train
# Out:
#           id                                  heartbeat_signals  label
# 0          0  0.9912297987616655,0.9435330436439665,0.764677...    0.0
# 1          1  0.9714822034884503,0.9289687459588268,0.572932...    0.0
# 2          2  1.0,0.9591487564065292,0.7013782792997189,0.23...    2.0
# 3          3  0.9757952826275774,0.9340884687738161,0.659636...    0.0
# 4          4  0.0,0.055816398940721094,0.26129357194994196,0...    2.0
# ...      ...                                                ...    ...
# 99995  99995  1.0,0.677705342021188,0.22239242747868546,0.25...    0.0
# 99996  99996  0.9268571578157265,0.9063471198026871,0.636993...    2.0
# 99997  99997  0.9258351628306013,0.5873839035878395,0.633226...    3.0
# 99998  99998  1.0,0.9947621698382489,0.8297017704865509,0.45...    2.0
# 99999  99999  0.9259994004527861,0.916476635326053,0.4042900...    0.0
#
# [100000 rows x 3 columns]

# %%
train_data_total = []
for items in data_train.values:
    train_data_total.append([float(i) for i in items[1].split(',')])

# %%
print("共有 {} 个样本".format(len(train_data_total)))
print("每个样本维度为：{}".format(len(train_data_total[0])))

data_dim = len(train_data_total[0])
for idx in train_data_total:
    if len(idx) != data_dim:
        print("维度不统一")
# Out:
# 共有 100000 个样本
# 每个样本维度为：205

# %%
print(type(train_data_total))
# Out:
# <class 'list'>

# %%
train_data_total = np.array(train_data_total)
print(train_data_total.shape)
# Out:
# (100000, 205)

# %%
test_x = []
for items in data_test_A.values:
    test_x.append([float(i) for i in items[1].split(',')])

# %%
test_x = np.array(test_x)
print(test_x.shape)
# Out:
# (20000, 205)

# %%
train_label = data_train.label
train_label
# Out:
# 0        0.0
# 1        0.0
# 2        2.0
# 3        0.0
# 4        2.0
#         ...
# 99995    0.0
# 99996    2.0
# 99997    3.0
# 99998    2.0
# 99999    0.0
# Name: label, Length: 100000, dtype: float64

# %%
temp = []
for idx in train_label:
    temp.append(int(idx))

# %%
train_label = temp
print(len(train_label))
# Out:
# 100000

# %%
train_label = to_categorical(train_label)
train_label.shape
# Out:
# (100000, 4)

# %%
model = Sequential()
model.add(Dense(128, input_shape=(205,), activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(4, activation='softmax'))
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               26368
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 260
# =================================================================
# Total params: 34,884
# Trainable params: 34,884
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_x = train_data_total[1000:]
train_y = train_label[1000:]

val_x = train_data_total[:1000]
val_y = train_label[:1000]

print("全量数据维度为: {}".format(train_data_total.shape))
print("全量标签维度为: {}".format(train_label.shape))

print("训练集数据维度为: {}".format(train_x.shape))
print("训练集标签维度为: {}".format(train_y.shape))

print("验证集数据维度为: {}".format(val_x.shape))
print("验证集标签维度为: {}".format(val_y.shape))

print("测试集数据维度为: {}".format(test_x.shape))
# Out:
# 全量数据维度为: (100000, 205)
# 全量标签维度为: (100000, 4)
# 训练集数据维度为: (99000, 205)
# 训练集标签维度为: (99000, 4)
# 验证集数据维度为: (1000, 205)
# 验证集标签维度为: (1000, 4)
# 测试集数据维度为: (20000, 205)

# %%
print(train_x[0,1])
print(type(train_x[0, 1]))
# Out:
# 0.8164311229285389
# <class 'numpy.float64'>

# %%
history = model.fit(train_x, train_y, epochs=10, batch_size=512, validation_data=(val_x, val_y))
# Out:
# Epoch 1/10
# 194/194 [==============================] - 1s 5ms/step - loss: 0.1687 - accuracy: 0.9454 - val_loss: 0.1915 - val_accuracy: 0.9430
# Epoch 2/10
# 194/194 [==============================] - 2s 9ms/step - loss: 0.1508 - accuracy: 0.9523 - val_loss: 0.1704 - val_accuracy: 0.9460
# Epoch 3/10
# 194/194 [==============================] - 2s 9ms/step - loss: 0.1365 - accuracy: 0.9573 - val_loss: 0.1659 - val_accuracy: 0.9480
# Epoch 4/10
# 194/194 [==============================] - 1s 5ms/step - loss: 0.1264 - accuracy: 0.9607 - val_loss: 0.1472 - val_accuracy: 0.9520
# Epoch 5/10
# 194/194 [==============================] - 1s 5ms/step - loss: 0.1188 - accuracy: 0.9628 - val_loss: 0.1529 - val_accuracy: 0.9560
# Epoch 6/10
# 194/194 [==============================] - 1s 5ms/step - loss: 0.1101 - accuracy: 0.9665 - val_loss: 0.1393 - val_accuracy: 0.9590
# Epoch 7/10
# 194/194 [==============================] - 1s 5ms/step - loss: 0.1047 - accuracy: 0.9679 - val_loss: 0.1336 - val_accuracy: 0.9600
# Epoch 8/10
# 194/194 [==============================] - 1s 4ms/step - loss: 0.0989 - accuracy: 0.9701 - val_loss: 0.1330 - val_accuracy: 0.9590
# Epoch 9/10
# 194/194 [==============================] - 1s 5ms/step - loss: 0.0942 - accuracy: 0.9712 - val_loss: 0.1170 - val_accuracy: 0.9640
# Epoch 10/10
# 194/194 [==============================] - 1s 6ms/step - loss: 0.0905 - accuracy: 0.9722 - val_loss: 0.1126 - val_accuracy: 0.9650

# %%
pred_result = model.predict(test_x)

# %%
print(pred_result.shape)
# Out:
# (20000, 4)

# %%
for idx in range(100):
    print(pred_result[idx])
# Out:
# [9.9553347e-01 4.3735681e-03 1.1963969e-06 9.1736096e-05]
# [1.9612379e-04 4.1965012e-02 9.5783865e-01 2.4869672e-07]
# [2.8294045e-04 8.6557935e-07 5.4040884e-05 9.9966216e-01]
# [9.8923898e-01 1.0485719e-02 2.7532500e-04 2.4705450e-08]
# [9.9929786e-01 4.1728519e-04 3.9904284e-05 2.4490559e-04]
# [9.489111e-01 5.100823e-02 8.070125e-05 7.513568e-08]
# [9.9466670e-01 3.5132255e-04 2.5854750e-05 4.9561863e-03]
# [9.8000491e-01 7.7081105e-04 1.3371751e-03 1.7887028e-02]
# [9.0960878e-01 9.0379044e-02 1.0516880e-05 1.6518375e-06]
# [3.7018428e-05 3.5399000e-11 1.8250391e-08 9.9996293e-01]
# [9.7184891e-01 2.2792039e-02 4.9364651e-03 4.2255907e-04]
# [8.3242548e-01 1.4794517e-03 1.6609505e-01 3.2381180e-08]
# [7.9672807e-01 1.9177887e-01 1.1068311e-02 4.2472829e-04]
# [9.9391913e-01 5.9742872e-03 1.0537226e-04 1.1473600e-06]
# [9.8793739e-01 1.1999662e-02 3.3716475e-05 2.9228335e-05]
# [9.9386108e-01 6.1367936e-03 2.1532617e-06 3.2507157e-09]
# [9.97067988e-01 2.91843549e-03 3.39024353e-07 1.31755805e-05]
# [2.5931987e-04 6.2179070e-06 9.9874097e-01 9.9358370e-04]
# [2.8112784e-01 3.8907689e-01 3.2965842e-01 1.3696478e-04]
# [2.1589816e-02 2.9435742e-04 5.7389552e-04 9.7754192e-01]
# [9.9883002e-01 9.7098766e-04 1.8187016e-04 1.7088618e-05]
# [8.192509e-06 4.114889e-10 4.543786e-08 9.999918e-01]
# [9.9532408e-01 4.6370700e-03 4.0521664e-07 3.8516253e-05]
# [0.13588704 0.00380875 0.00358028 0.8567239 ]
# [9.9780661e-01 2.0654497e-03 8.2380766e-06 1.1972741e-04]
# [9.3111938e-01 6.5537795e-02 3.3414268e-03 1.4187071e-06]
# [2.45732497e-02 2.28766142e-03 9.73032117e-01 1.06924665e-04]
# [9.8753989e-01 1.1866922e-02 1.1765821e-07 5.9314579e-04]
# [9.9723911e-01 2.4284974e-03 3.3243833e-04 2.5746946e-08]
# [9.7790843e-01 2.1013606e-02 2.7678945e-04 8.0120558e-04]
# [9.8727661e-01 1.2722360e-02 6.1280116e-07 5.0034117e-07]
# [9.9915695e-01 8.4296911e-04 8.1387689e-08 5.2303562e-08]
# [3.1949133e-02 9.6782315e-01 2.2515826e-04 2.5195566e-06]
# [9.8937619e-01 1.0525729e-02 3.0101617e-08 9.8160548e-05]
# [9.8734647e-01 1.2651667e-02 1.9077717e-08 1.8918371e-06]
# [9.5899761e-01 4.0981449e-02 1.7909964e-05 2.9265782e-06]
# [9.9775583e-01 1.7277652e-03 4.4946067e-04 6.6939661e-05]
# [9.9683517e-01 3.1625985e-03 4.2909619e-07 1.7910615e-06]
# [9.3934751e-01 5.5519897e-02 4.9081184e-03 2.2440891e-04]
# [0.386229   0.00733291 0.00069134 0.60574675]
# [9.3880558e-01 6.1191119e-02 3.2379166e-06 5.6648421e-08]
# [6.7111933e-01 3.2887343e-01 6.9121379e-06 3.0473157e-07]
# [9.8403716e-01 1.4679473e-02 7.4730022e-04 5.3605379e-04]
# [9.8078960e-01 1.9209376e-02 9.2173815e-07 6.9421318e-08]
# [9.935434e-01 6.332395e-03 4.632247e-05 7.793400e-05]
# [9.7948074e-01 2.0494577e-02 2.4470137e-05 1.3351834e-07]
# [9.9792933e-01 1.1168712e-04 1.9574044e-03 1.5322922e-06]
# [0.17054038 0.21458696 0.61379313 0.00107945]
# [1.5518656e-03 7.7350865e-05 5.5453978e-02 9.4291675e-01]
# [9.9082375e-01 9.1520753e-03 1.6937661e-07 2.4076739e-05]
# [9.6137506e-01 3.4603872e-03 3.5152905e-02 1.1673462e-05]
# [0.97767717 0.00710953 0.01401293 0.00120032]
# [7.4451200e-05 5.8399921e-05 9.9986708e-01 1.3475035e-13]
# [2.1186142e-04 2.8007091e-05 9.9976009e-01 1.7797888e-11]
# [9.9959451e-01 3.8245061e-04 2.2584662e-05 3.3820629e-07]
# [9.6465832e-01 3.4967866e-02 3.0563827e-04 6.8231915e-05]
# [9.67764735e-01 2.92987935e-02 1.07109416e-04 2.82939617e-03]
# [9.9417287e-01 5.2111573e-03 6.1580032e-04 1.6455988e-07]
# [9.8154503e-01 1.1077320e-02 7.2596418e-03 1.1810123e-04]
# [9.98658895e-01 1.33007404e-03 1.09547345e-05 1.25228269e-07]
# [9.9841261e-01 1.5873580e-03 4.3593555e-08 4.2929326e-08]
# [9.7937393e-01 2.0583158e-02 2.6019590e-05 1.6934613e-05]
# [9.7925067e-01 2.0689132e-02 2.2516403e-07 6.0015864e-05]
# [5.2610284e-04 1.6679753e-06 9.1298716e-05 9.9938095e-01]
# [9.9301469e-01 3.1918972e-03 3.7808705e-03 1.2598928e-05]
# [9.9766457e-01 2.3352355e-03 2.1859512e-08 2.7527946e-07]
# [9.2460150e-01 7.4993476e-02 3.1459989e-04 9.0497808e-05]
# [4.61159623e-04 1.47043265e-05 9.99031663e-01 4.92409279e-04]
# [1.6348627e-04 8.3702774e-04 9.9899620e-01 3.3321026e-06]
# [0.79575634 0.00207102 0.01059214 0.19158049]
# [9.9105608e-01 8.8524260e-03 6.1028775e-05 3.0347041e-05]
# [1.3640954e-05 7.1195098e-11 1.5667965e-08 9.9998629e-01]
# [9.5498586e-01 4.5010038e-02 1.5291482e-08 4.0928885e-06]
# [3.7302837e-02 3.7533324e-04 7.1516092e-04 9.6160662e-01]
# [9.9371850e-01 6.2781074e-03 1.7288330e-06 1.6546777e-06]
# [4.1361764e-04 4.3521725e-04 9.9914467e-01 6.4122678e-06]
# [9.9055499e-01 8.9211687e-03 5.2364706e-04 6.9025532e-08]
# [1.9406860e-03 9.9761677e-01 4.4248879e-04 4.1079535e-09]
# [7.2301391e-06 5.6329455e-11 1.3339586e-08 9.9999273e-01]
# [9.7632307e-01 2.3609325e-02 6.7426350e-05 2.5586615e-07]
# [9.9900788e-01 7.5191684e-04 8.3960338e-05 1.5622930e-04]
# [9.9876451e-01 1.9071873e-04 1.0437411e-03 1.1072406e-06]
# [9.7178686e-01 1.4697975e-02 4.9752698e-06 1.3510162e-02]
# [8.4102958e-01 1.5896134e-01 9.1491820e-06 3.0829483e-08]
# [4.6533564e-06 2.4258037e-07 9.9999511e-01 7.3757953e-12]
# [9.6095914e-01 1.6191730e-02 2.2843579e-02 5.6333183e-06]
# [0.18005852 0.11126892 0.70681477 0.0018577 ]
# [9.9820650e-01 1.7933554e-03 8.6898240e-08 3.8526821e-08]
# [9.5451063e-01 4.5257129e-02 2.3218164e-04 3.2913544e-08]
# [1.4693904e-04 8.7013959e-08 1.0189119e-05 9.9984276e-01]
# [9.4789207e-01 4.8628155e-02 3.4511329e-03 2.8639462e-05]
# [9.9947971e-01 5.1897689e-04 8.8812931e-07 4.6704727e-07]
# [9.9834228e-01 1.6571117e-03 9.0917460e-08 4.9489523e-07]
# [9.9385464e-01 3.7755159e-04 5.7668518e-03 8.9569266e-07]
# [9.9887425e-01 1.1115656e-03 1.7014477e-08 1.4188681e-05]
# [8.8958064e-04 8.1547732e-05 1.1369715e-04 9.9891520e-01]
# [9.9581236e-01 4.1860398e-03 1.3238003e-06 2.8854558e-07]
# [9.5857626e-01 4.1276339e-02 1.4685857e-04 5.4840888e-07]
# [9.8820913e-01 7.9537416e-03 3.8349105e-03 2.2428590e-06]
# [9.9303353e-01 6.2082116e-03 7.5711851e-04 1.0355053e-06]

# %%
pred_result[0]
# Out:
# array([9.9553347e-01, 4.3735681e-03, 1.1963969e-06, 9.1736096e-05],
#       dtype=float32)

# %%
print(pred_result.shape)
# Out:
# (20000, 4)

# %%
result0 = []
result1 = []
result2 = []
result3 = []
for idx in range(len(pred_result)):
    result0.append(pred_result[idx][0])
    result1.append(pred_result[idx][1])
    result2.append(pred_result[idx][2])
    result3.append(pred_result[idx][3])
result0
# Out:
# [0.99553347,
#  0.00019612379,
#  0.00028294045,
#  0.989239,
#  0.99929786,
#  0.9489111,
#  0.9946667,
#  0.9800049,
#  0.9096088,
#  3.7018428e-05,
#  0.9718489,
#  0.8324255,
#  0.7967281,
#  0.99391913,
#  0.9879374,
#  0.9938611,
#  0.997068,
#  0.00025931987,
#  0.28112784,
#  0.021589816,
#  0.99883,
#  8.192509e-06,
#  0.9953241,
#  0.13588704,
#  0.9978066,
#  0.9311194,
#  0.02457325,
#  0.9875399,
#  0.9972391,
#  0.97790843,
#  0.9872766,
#  0.99915695,
#  0.031949133,
#  0.9893762,
#  0.9873465,
#  0.9589976,
#  0.9977558,
#  0.9968352,
#  0.9393475,
#  0.386229,
#  0.9388056,
#  0.67111933,
#  0.98403716,
#  0.9807896,
#  0.9935434,
#  0.97948074,
#  0.99792933,
#  0.17054038,
#  0.0015518656,
#  0.99082375,
#  0.96137506,
#  0.97767717,
#  7.44512e-05,
#  0.00021186142,
#  0.9995945,
#  0.9646583,
#  0.96776474,
#  0.9941729,
#  0.98154503,
#  0.9986589,
#  0.9984126,
#  0.97937393,
#  0.97925067,
#  0.00052610284,
#  0.9930147,
#  0.9976646,
#  0.9246015,
#  0.00046115962,
#  0.00016348627,
#  0.79575634,
#  0.9910561,
#  1.3640954e-05,
#  0.95498586,
#  0.037302837,
#  0.9937185,
#  0.00041361764,
#  0.990555,
#  0.001940686,
#  7.230139e-06,
#  0.97632307,
#  0.9990079,
#  0.9987645,
#  0.97178686,
#  0.8410296,
#  4.6533564e-06,
#  0.96095914,
#  0.18005852,
#  0.9982065,
#  0.9545106,
#  0.00014693904,
#  0.94789207,
#  0.9994797,
#  0.9983423,
#  0.99385464,
#  0.99887425,
#  0.00088958064,
#  0.99581236,
#  0.95857626,
#  0.9882091,
#  0.9930335,
#  0.97168106,
#  0.95221645,
#  0.92311954,
#  0.81653655,
#  0.996554,
#  0.9601889,
#  1.1006263e-05,
#  0.9933467,
#  0.99904734,
#  0.9982444,
#  0.52588403,
#  0.0008546143,
#  0.0006740899,
#  0.99842864,
#  0.037929874,
#  0.9810889,
#  7.0620117e-06,
#  0.000654438,
#  0.9914614,
#  0.00069572986,
#  0.33255944,
#  6.0388073e-05,
#  0.96823055,
#  0.9797861,
#  0.7791529,
#  0.9964561,
#  0.979803,
#  0.019012019,
#  0.0015603815,
#  0.96396315,
#  0.026951708,
#  0.002254703,
#  0.0004981245,
#  0.0017687773,
#  0.9954615,
#  0.9960789,
#  0.00011016025,
#  0.99750715,
#  0.99685115,
#  0.00015229931,
#  0.83627397,
#  0.006149819,
#  0.99979264,
#  0.20790043,
#  0.9454682,
#  0.99724686,
#  0.99626833,
#  0.0024116647,
#  0.0043472494,
#  0.7751469,
#  0.98822427,
#  5.3491884e-05,
#  0.99844813,
#  0.0010380911,
#  0.9808444,
#  1.2450558e-05,
#  0.99691665,
#  0.9910262,
#  0.97323024,
#  0.9902954,
#  0.0061391946,
#  0.00079576904,
#  5.9368745e-06,
#  0.9127555,
#  0.9949361,
#  0.45999172,
#  0.993471,
#  0.9990451,
#  0.98682874,
#  0.99625325,
#  0.9982343,
#  0.90027106,
#  0.95811445,
#  0.993182,
#  0.9995028,
#  0.4128224,
#  1.5654532e-05,
#  0.028172793,
#  0.9837045,
#  0.9978446,
#  3.9593513e-05,
#  0.0022316908,
#  0.9974064,
#  0.98905784,
#  0.98804736,
#  0.99812895,
#  0.9871358,
#  0.0023342005,
#  4.3961314e-05,
#  0.9799642,
#  0.99966455,
#  0.99455535,
#  0.8423208,
#  0.23442252,
#  0.9971282,
#  0.007591449,
#  0.9990638,
#  0.99533135,
#  0.88804454,
#  0.99648786,
#  0.12241247,
#  0.9643049,
#  7.58769e-06,
#  0.9508664,
#  0.00011563719,
#  2.0372758e-05,
#  0.0003523042,
#  4.185894e-06,
#  0.99665534,
#  0.060210217,
#  0.0026960187,
#  1.8183877e-05,
#  0.0038862424,
#  0.97928226,
#  0.004315057,
#  0.99247605,
#  0.96609294,
#  0.9934342,
#  0.9916312,
#  0.9987116,
#  0.00238671,
#  0.99844414,
#  0.48397917,
#  0.9842569,
#  0.011780817,
#  0.8661118,
#  0.9584863,
#  0.94724375,
#  0.9922139,
#  0.010411808,
#  0.0014360141,
#  0.0017426438,
#  0.8501951,
#  0.99568826,
#  0.99096113,
#  0.9972289,
#  0.989078,
#  0.00014347874,
#  0.949281,
#  0.97846824,
#  0.9859433,
#  7.3274496e-05,
#  0.034504287,
#  0.99386877,
#  3.7780137e-05,
#  0.89223415,
#  0.96387786,
#  0.9432341,
#  0.9859444,
#  0.00018962186,
#  0.407302,
#  0.0070916964,
#  0.00029015902,
#  0.9814767,
#  0.952566,
#  0.9947497,
#  0.99870586,
#  0.9174934,
#  0.99127394,
#  9.298245e-05,
#  0.00018796873,
#  0.0008836015,
#  1.0454528e-05,
#  0.3374228,
#  0.96896154,
#  0.99862707,
#  3.1129424e-05,
#  0.94157094,
#  0.0005043183,
#  0.99097896,
#  0.0015791953,
#  0.9996923,
#  0.0048212283,
#  0.9593885,
#  0.9524886,
#  0.92684287,
#  2.2431419e-05,
#  0.96481663,
#  0.9992287,
#  0.9390471,
#  0.77805346,
#  0.35004908,
#  1.594595e-05,
#  0.88533264,
#  0.9449092,
#  0.9988813,
#  3.501725e-06,
#  0.9967158,
#  0.73497736,
#  0.00042398024,
#  0.00024024918,
#  0.98750263,
#  0.89241755,
#  0.9366334,
#  0.99281317,
#  0.98657775,
#  0.025602246,
#  0.9968387,
#  4.8644877e-05,
#  0.87176794,
#  0.98563516,
#  0.99935216,
#  0.997274,
#  0.96309584,
#  0.8887215,
#  0.9627693,
#  0.9960938,
#  0.9764128,
#  0.97758144,
#  0.8436064,
#  0.110907376,
#  0.95669335,
#  0.9977944,
#  6.0762545e-06,
#  0.9721904,
#  0.007311779,
#  6.276899e-05,
#  3.260686e-05,
#  0.99538785,
#  0.9965835,
#  0.0012266509,
#  0.9941129,
#  0.9397662,
#  0.99901855,
#  0.001060475,
#  0.9991517,
#  0.85936016,
#  0.9925452,
#  0.9812119,
#  0.00015327196,
#  7.03301e-05,
#  0.9991493,
#  0.9397019,
#  0.99821967,
#  0.9916739,
#  0.9834663,
#  0.9969566,
#  0.99460274,
#  0.73744667,
#  0.9821414,
#  0.41328847,
#  0.99761957,
#  0.9963547,
#  0.7316664,
#  0.965538,
#  0.979905,
#  0.98799825,
#  0.3656211,
#  0.44141737,
#  0.99892896,
#  0.95855457,
#  0.00011726086,
#  0.7859156,
#  0.8577258,
#  0.9860576,
#  8.361682e-05,
#  7.1906805e-05,
#  0.9967619,
#  0.989595,
#  0.99295807,
#  0.9990281,
#  0.98960155,
#  0.99634236,
#  0.99647236,
#  0.85359836,
#  0.297922,
#  0.0046054083,
#  0.9973526,
#  0.9911122,
#  0.07975093,
#  0.8698605,
#  0.99239916,
#  0.97780913,
#  0.96667427,
#  0.0001222852,
#  0.98205894,
#  0.0014046085,
#  0.89320415,
#  0.91096663,
#  0.0019907653,
#  0.9981621,
#  0.994238,
#  0.9858699,
#  5.006141e-05,
#  6.7893125e-05,
#  0.021149846,
#  0.8201255,
#  0.98122555,
#  0.9455522,
#  0.9671715,
#  0.3028917,
#  0.9385266,
#  0.9715305,
#  0.98587066,
#  0.00016139685,
#  0.00012802571,
#  0.9837647,
#  0.0017288978,
#  0.016572129,
#  0.99342877,
#  7.758891e-05,
#  2.014585e-06,
#  0.006013678,
#  0.040577177,
#  1.8761996e-06,
#  0.00023977381,
#  0.9992735,
#  0.9978167,
#  0.9380593,
#  0.946613,
#  0.98176366,
#  0.00066086365,
#  0.99876285,
#  0.00023755245,
#  0.00067946647,
#  0.9937615,
#  0.008478873,
#  3.5618323e-05,
#  0.92631024,
#  0.9968352,
#  2.1854396e-06,
#  1.1315583e-06,
#  0.99972934,
#  0.00016456029,
#  0.0063439133,
#  0.9772997,
#  0.99915075,
#  0.9943057,
#  0.9988759,
#  0.992959,
#  0.99856323,
#  0.97822696,
#  0.9432829,
#  0.99011713,
#  0.99860805,
#  0.00042376432,
#  0.97564644,
#  3.722707e-06,
#  0.9923881,
#  0.2203924,
#  0.0019850198,
#  0.81039435,
#  0.9996556,
#  0.00013086689,
#  0.0012856547,
#  6.4273954e-05,
#  0.99330515,
#  0.1463224,
#  0.962237,
#  0.99871683,
#  0.0025296637,
#  0.99555874,
#  0.92022336,
#  0.003781783,
#  0.9972452,
#  0.97845596,
#  0.9929819,
#  0.9037499,
#  0.97316813,
#  0.99418056,
#  0.00010540038,
#  0.998938,
#  0.9941837,
#  0.9362842,
#  0.99415094,
#  0.9796933,
#  9.866776e-06,
#  0.02408795,
#  0.99675167,
#  0.0004690855,
#  0.9928098,
#  5.9471677e-05,
#  0.9880201,
#  0.99468094,
#  0.9955369,
#  0.99700135,
#  0.93463707,
#  0.9911521,
#  0.98922473,
#  0.99886596,
#  0.99143326,
#  0.9996051,
#  0.9979851,
#  0.0005483558,
#  0.99237293,
#  0.99674654,
#  0.9858461,
#  0.74357766,
#  0.96107846,
#  0.0030202544,
#  0.98236,
#  0.2023677,
#  0.988886,
#  0.9940491,
#  0.9430619,
#  0.35163164,
#  0.007650523,
#  0.0026564011,
#  0.000796217,
#  0.0012571524,
#  0.99171877,
#  0.9878392,
#  0.0002738681,
#  0.0003918735,
#  0.00032890297,
#  0.9976719,
#  0.9970572,
#  0.9914521,
#  0.9958377,
#  4.7727344e-06,
#  0.9992385,
#  0.9993849,
#  0.99172837,
#  0.99734324,
#  0.9954726,
#  0.9893807,
#  0.0023105242,
#  0.99935156,
#  3.5874857e-06,
#  0.8956905,
#  8.139931e-05,
#  0.96967715,
#  0.95237136,
#  4.6651447e-05,
#  0.99442166,
#  0.00033872228,
#  0.9968424,
#  0.9962967,
#  0.045245875,
#  0.9857091,
#  4.217456e-05,
#  0.0030891357,
#  0.94679815,
#  5.0669456e-05,
#  0.9958526,
#  0.0023279386,
#  4.113001e-05,
#  0.99403644,
#  0.0109330695,
#  0.016164415,
#  0.9977977,
#  0.00011925738,
#  0.000113173286,
#  2.084021e-06,
#  0.9941162,
#  0.00029160068,
#  0.9908144,
#  0.9908125,
#  0.996761,
#  0.99222845,
#  6.534578e-05,
#  0.9972608,
#  0.925757,
#  0.97511476,
#  0.9824584,
#  0.9924573,
#  0.9887394,
#  0.1668718,
#  0.5351427,
#  0.99490154,
#  0.98770124,
#  0.99487174,
#  0.9660005,
#  0.9356072,
#  0.9973109,
#  0.0007194762,
#  8.728546e-05,
#  0.97610295,
#  0.9604609,
#  0.99068165,
#  8.8475805e-05,
#  0.9882237,
#  0.99637526,
#  0.00012151343,
#  0.9936813,
#  0.96058387,
#  0.831783,
#  0.9918628,
#  0.0033675947,
#  0.00018414686,
#  0.9964187,
#  0.971048,
#  0.46930385,
#  0.99275357,
#  0.9960771,
#  0.99789196,
#  0.40046385,
#  1.08870245e-05,
#  0.9546539,
#  0.99176735,
#  0.00010297377,
#  0.9953147,
#  0.9908289,
#  2.346289e-05,
#  0.0013199162,
#  0.017727196,
#  2.5162399e-05,
#  0.40174937,
#  0.9988877,
#  0.002366334,
#  0.9720515,
#  0.91504496,
#  0.97776765,
#  0.99777657,
#  0.9988932,
#  0.0014302541,
#  2.6051064e-05,
#  0.8436765,
#  0.9696679,
#  0.9983652,
#  0.99586284,
#  0.9643874,
#  0.9189253,
#  2.6823093e-06,
#  1.1136371e-05,
#  0.9915911,
#  0.0015288886,
#  0.9928295,
#  4.914469e-05,
#  0.99230313,
#  9.57619e-05,
#  0.00014213746,
#  0.9937302,
#  0.89659506,
#  0.00030329646,
#  0.9882166,
#  0.99852896,
#  0.0011186193,
#  0.99478745,
#  0.00034209152,
#  0.94621474,
#  0.031530134,
#  0.9977944,
#  5.513141e-05,
#  0.99077857,
#  0.98619324,
#  0.030755782,
#  0.86547947,
#  0.9590287,
#  0.99447757,
#  0.98145354,
#  0.997336,
#  0.9706542,
#  0.98760545,
#  0.9877203,
#  0.9967962,
#  0.002716581,
#  0.29555288,
#  0.00012305523,
#  0.96483886,
#  0.91992706,
#  0.005890269,
#  0.92042387,
#  0.99719137,
#  0.97628003,
#  0.75717753,
#  0.0011366794,
#  0.0017196975,
#  0.6049117,
#  0.004334881,
#  0.9867285,
#  0.99511635,
#  0.31627926,
#  0.00013993909,
#  0.961651,
#  0.9541322,
#  7.218047e-05,
#  0.97720325,
#  0.9998204,
#  0.9962386,
#  0.9854074,
#  0.99482816,
#  0.0011029106,
#  0.18210648,
#  0.9916856,
#  0.997512,
#  0.0035136123,
#  0.93739426,
#  0.9998491,
#  0.09167557,
#  0.98297125,
#  0.9550601,
#  2.0067015e-05,
#  0.00016092636,
#  0.9702288,
#  8.025208e-05,
#  8.5506486e-05,
#  0.6690648,
#  0.9589773,
#  0.99975044,
#  0.00018146417,
#  0.9934778,
#  0.96331006,
#  0.98910517,
#  0.029791407,
#  0.016647827,
#  0.9994197,
#  0.9648457,
#  0.006756088,
#  0.9837114,
#  0.96509296,
#  2.8770724e-05,
#  0.99759954,
#  2.471623e-06,
#  0.00047466578,
#  0.998899,
#  0.0002555004,
#  0.99460125,
#  0.9948998,
#  0.99576926,
#  0.00047826237,
#  0.9921124,
#  0.6886819,
#  0.8930464,
#  0.9662207,
#  0.99833137,
#  0.0039779623,
#  0.9910086,
#  0.9533571,
#  0.9989135,
#  0.9996014,
#  0.9033565,
#  4.323526e-05,
#  0.94660616,
#  0.99412954,
#  0.9782779,
#  0.9982492,
#  0.80157,
#  9.503382e-05,
#  0.9630088,
#  0.88279086,
#  0.99018127,
#  0.0026935753,
#  0.18782961,
#  0.993188,
#  0.99599874,
#  0.9647669,
#  0.9279949,
#  0.9722014,
#  0.00045006233,
#  5.4180666e-05,
#  0.9896125,
#  0.99895954,
#  0.9312581,
#  0.9866028,
#  0.017911483,
#  0.99096644,
#  0.9890155,
#  0.9867121,
#  0.995285,
#  0.9971923,
#  0.99971753,
#  0.00024261784,
#  0.9990331,
#  0.97430915,
#  0.00061953446,
#  0.0011614262,
#  0.7816161,
#  0.0014544869,
#  0.974052,
#  0.0020748568,
#  0.99442494,
#  0.09579244,
#  0.99600214,
#  0.00043976292,
#  0.97573143,
#  0.051000588,
#  0.0005113674,
#  0.00034446866,
#  0.98692,
#  0.00026863904,
#  0.9923534,
#  0.8869061,
#  8.12808e-05,
#  0.007431529,
#  0.0035018334,
#  0.94173414,
#  0.003262564,
#  0.04498573,
#  0.9965383,
#  0.00038513562,
#  0.98908126,
#  0.9861936,
#  0.0003494921,
#  0.019449422,
#  0.9254518,
#  0.001052682,
#  6.6025054e-06,
#  0.00026217042,
#  0.99583,
#  0.9986871,
#  0.00014223103,
#  0.9806826,
#  0.0016104166,
#  0.0032738,
#  0.9625974,
#  0.00014589592,
#  3.230965e-05,
#  0.9206459,
#  0.9726,
#  0.9637933,
#  0.00088434527,
#  0.0033570586,
#  0.9977087,
#  0.98936594,
#  0.00047713256,
#  0.0036628041,
#  0.000176656,
#  0.994038,
#  0.0007385565,
#  0.89571744,
#  0.9985815,
#  0.9850483,
#  0.5343589,
#  2.0392978e-05,
#  0.28568834,
#  9.7721364e-05,
#  0.9936963,
#  0.9143712,
#  0.9996282,
#  0.9652644,
#  0.017095624,
#  0.2631142,
#  0.530545,
#  0.84381926,
#  0.97156185,
#  0.9964561,
#  4.2308555e-05,
#  0.00016412431,
#  0.00016811248,
#  0.00015118398,
#  0.99817705,
#  0.22754723,
#  0.98435175,
#  0.9945748,
#  0.9786219,
#  0.99468476,
#  0.99664694,
#  0.00018386528,
#  0.9414998,
#  0.8822313,
#  0.001039894,
#  0.990831,
#  0.9988951,
#  0.9692415,
#  0.9819626,
#  0.9957443,
#  0.9983335,
#  0.9905503,
#  0.00011019998,
#  0.0002342453,
#  0.9874013,
#  0.02841566,
#  0.99348587,
#  0.99777836,
#  0.9967686,
#  0.9871243,
#  0.98576176,
#  0.95679986,
#  0.9180988,
#  0.99042016,
#  0.99356234,
#  0.99845016,
#  0.99971086,
#  0.99738926,
#  0.83207864,
#  0.9891396,
#  0.00022976083,
#  0.9942052,
#  0.0031695045,
#  0.7170092,
#  0.9972051,
#  0.9986628,
#  0.7733885,
#  0.9245241,
#  1.9362185e-05,
#  0.00052756496,
#  0.987298,
#  0.8133012,
#  3.7110363e-05,
#  0.99986947,
#  0.075995065,
#  0.99557674,
#  0.9993759,
#  0.9965579,
#  0.997147,
#  0.9912074,
#  0.9366964,
#  2.1424863e-05,
#  2.159025e-06,
#  0.5065123,
#  0.9710513,
#  0.05637011,
#  0.9617378,
#  0.99390763,
#  0.0012220038,
#  0.9891317,
#  0.99903333,
#  0.9924103,
#  0.66009223,
#  0.7571049,
#  0.8232156,
#  0.02607416,
#  0.0005589085,
#  0.99853814,
#  4.9296963e-05,
#  0.00013938773,
#  0.00084847276,
#  0.903525,
#  0.14651898,
#  0.0008500166,
#  0.9979107,
#  0.8995079,
#  0.9951402,
#  0.020002238,
#  0.9945147,
#  0.00035001323,
#  0.95531785,
#  1.7524104e-05,
#  0.5486838,
#  0.98895943,
#  0.0016791463,
#  0.97479284,
#  0.9158711,
#  0.00069880247,
#  0.984445,
#  8.411638e-05,
#  0.9930568,
#  0.9379675,
#  0.89028764,
#  0.99318105,
#  0.84827936,
#  9.5538635e-05,
#  6.069403e-05,
#  0.0035826871,
#  0.9991666,
#  0.9887721,
#  0.9854779,
#  0.0067809545,
#  0.8285427,
#  0.95621234,
#  0.00020462571,
#  0.9825796,
#  0.9937955,
#  0.9860037,
#  0.9904818,
#  0.9975689,
#  0.99332035,
#  0.9903307,
#  0.6902254,
#  0.99269426,
#  0.9900041,
#  7.9343765e-05,
#  0.99788827,
#  0.9963773,
#  0.8140665,
#  0.9380607,
#  0.96636057,
#  0.9969199,
#  0.9905111,
#  0.9945551,
#  0.98080015,
#  0.99123996,
#  0.9996158,
#  0.9254299,
#  5.7104207e-05,
#  0.9638994,
#  0.9991654,
#  0.000628064,
#  0.00025111623,
#  1.4907171e-05,
#  0.9028089,
#  0.9994599,
#  0.93672013,
#  0.00042715942,
#  0.99739456,
#  0.8103305,
#  0.9891262,
#  1.5900701e-05,
#  2.243008e-06,
#  0.9538972,
#  0.70860344,
#  0.9686668,
#  0.9936737,
#  0.98871475,
#  0.0051465984,
#  0.967224,
#  0.9852549,
#  0.9940544,
#  0.96988666,
#  0.9904157,
#  0.9995732,
#  0.0013796188,
#  0.00014197388,
#  0.0023190738,
#  0.0029669635,
#  0.00035894965,
#  0.12550849,
#  0.001476818,
#  0.96507716,
#  ...]

# %%
result_data = pd.read_csv(data_path + 'sample_submit.csv')

result_data['label_0']=result0
result_data['label_1']=result1
result_data['label_2']=result2
result_data['label_3']=result3
result_data.to_csv('./20210317_submit.csv',index=False)
